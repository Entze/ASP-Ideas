# %%
import abc
from collections import defaultdict, namedtuple
from copy import deepcopy
from dataclasses import dataclass, field
from enum import IntEnum
from typing import MutableSequence
from typing import Optional, Iterator, Sequence, TypeVar, Set, Mapping, Union, Tuple, Iterable, FrozenSet

import clingo
import clingraph
from clingraph import Factbase, compute_graphs
from more_itertools import powerset

# %%
def asp_solve(programs,
              ctl: Optional[clingo.Control] = None,
              parts=(('base', ()),),
              context=None,
              report=False,
              report_models=True,
              report_result=True,
              symbol_sep=' ',
              model_sep='\n'
              ) -> Iterator[Sequence[clingo.Symbol]]:
    if ctl is None:
        ctl = clingo.Control(logger=lambda *args, **kwargs: None)
        ctl.configuration.solve.models = 0
    ctl.add('base', [], '\n'.join(programs))
    ctl.ground(parts, context=context)
    with ctl.solve(yield_=True) as solve_handle:
        models = 0
        for model in solve_handle:
            symbols = sorted(model.symbols(shown=True))
            if report and report_models:
                print("Answer {}:".format(model.number), end=' ')
                print("{",
                      symbol_sep.join(map(str, symbols)), "}", sep=symbol_sep, end=model_sep)
            models += 1
            yield symbols
        if report and report_result:
            solve_result = solve_handle.get()
            print(solve_result, end='')
            if solve_result.satisfiable:
                print(" {}{}".format(models, '' if solve_result.exhausted else '+'))
            else:
                print()


def draw_graph(programs,
               ctl: Optional[clingo.Control] = None,
               parts=(('base', ()),)):
    fb = Factbase()
    if ctl is None:
        ctl = clingo.Control(logger=lambda *args, **kwargs: None)
        ctl.configuration.solve.models = 0
    ctl.add('base', [], '\n'.join(programs))
    ctl.ground(parts, clingraph.clingo_utils.ClingraphContext())
    with ctl.solve(yield_=True) as solve_handle:
        for model in solve_handle:
            fb.add_model(model)
            break
    return compute_graphs(fb)

# %%
ForwardASPSymbol = TypeVar('ForwardASPSymbol', bound='ASPSymbol')
ForwardASPVariable = TypeVar('ForwardASPVariable', bound='ASPVariable')


class ASPSymbol(abc.ABC):

    @staticmethod
    def from_clingo_symbol(symbol: clingo.Symbol) -> ForwardASPSymbol:
        if symbol.type is clingo.SymbolType.Number:
            return ASPTerm(ASPIntegerConstant(symbol.number))
        elif symbol.type is clingo.SymbolType.String:
            return ASPTerm(ASPStringConstant(symbol.string))
        elif symbol.type is clingo.SymbolType.Function:
            arguments = tuple(ASPFunction.from_clingo_symbol(argument) for argument in symbol.arguments)
            name = symbol.name
            if symbol.negative:
                name = "-{}".format(name)
            return ASPFunction(name, arguments)
        else:
            assert False, "Unhandled clingo.Symbol {} with type {}.".format(symbol, symbol.type.name)


@dataclass(order=True, frozen=True)
class ASPStringConstant:
    string: str = field(default="")

    def __str__(self):
        return '"{}"'.format(self.string)


@dataclass(order=True, frozen=True)
class ASPIntegerConstant:
    number: int = field(default=0)

    def __str__(self):
        return str(self.number)


@dataclass(order=True, frozen=True)
class ASPTerm(ASPSymbol):
    constant: Union[ASPStringConstant, ASPIntegerConstant] = field(default_factory=ASPIntegerConstant)

    def __str__(self):
        return str(self.constant)

    @staticmethod
    def zero():
        return ASPTerm(ASPIntegerConstant(0))

    @staticmethod
    def one():
        return ASPTerm(ASPIntegerConstant(1))


ForwardASPTopLevelSymbol = TypeVar('ForwardASPTopLevelSymbol', bound='ASPTopLevelSymbol')


class ASPTopLevelSymbol(ASPSymbol, abc.ABC):

    @property
    def signature(self) -> str:
        return "{}/{}.".format(self.function_name, self.arity)

    @property
    @abc.abstractmethod
    def function_name(self) -> str:
        raise NotImplementedError

    @property
    def arity(self) -> int:
        return len(self.function_arguments)

    @property
    @abc.abstractmethod
    def function_arguments(self) -> Sequence[ASPSymbol]:
        raise NotImplementedError

    def match(self, other: ForwardASPTopLevelSymbol) -> bool:
        return self.function_name == other.function_name and len(self.function_arguments) == len(
            other.function_arguments)


def asp_evaluate(*programs, report=False) -> Iterator[FrozenSet[ASPTopLevelSymbol]]:
    for answer_set in asp_solve(programs=programs, report=report):
        yield frozenset(ASPFunction.from_clingo_symbol(symbol) for symbol in answer_set)


@dataclass(order=True, frozen=True)
class ASPFunction(ASPTopLevelSymbol):
    name: Optional[str] = field(default=None)
    arguments: Sequence[ASPSymbol] = field(default_factory=tuple)

    @property
    def function_name(self) -> str:
        return self.name

    @property
    def function_arguments(self) -> Sequence[ASPSymbol]:
        return self.arguments

    @property
    def arity(self) -> int:
        return len(self.arguments)

    def __str__(self):
        if self.name is None:
            return '({})'.format(','.join(map(str, self.arguments)))
        elif not self.arguments:
            return self.name
        else:
            return '{}({})'.format(self.name, ','.join(map(str, self.arguments)))


ForwardASPAtom = TypeVar('ForwardASPAtom', bound='ASPAtom')


@dataclass(order=True, frozen=True)
class ASPAtom:
    symbol: ASPTopLevelSymbol = field(default_factory=ASPFunction)

    @property
    def signature(self) -> str:
        return self.symbol.signature

    def match(self, other: ForwardASPAtom) -> bool:
        return self.symbol.function_name == other.symbol.function_name and len(self.symbol.function_arguments) == len(
            other.symbol.function_arguments)

    def __str__(self):
        return str(self.symbol)


@dataclass(order=True, frozen=True)
class ASPClauseElement(abc.ABC):

    @property
    @abc.abstractmethod
    def signature(self) -> str:
        raise NotImplementedError

    @property
    @abc.abstractmethod
    def is_pos(self):
        raise NotImplementedError

    @property
    @abc.abstractmethod
    def is_neg(self):
        raise NotImplementedError

    def __neg__(self):
        raise NotImplementedError

    def __abs__(self):
        raise NotImplementedError


class ASPHeadClauseElement(ASPClauseElement):
    pass


class ASPLiteral(ASPHeadClauseElement):

    @property
    @abc.abstractmethod
    def signature(self) -> str:
        raise NotImplementedError

    @property
    @abc.abstractmethod
    def is_pos(self) -> bool:
        raise NotImplementedError

    @property
    @abc.abstractmethod
    def is_neg(self) -> bool:
        raise NotImplementedError


class ASPSign(IntEnum):
    NoSign = 0
    Negation = 1

    def __str__(self):
        if self is ASPSign.NoSign:
            return ''
        elif self is ASPSign.Negation:
            return 'not'
        else:
            assert False, 'Unknown IntEnum {} = {}.'.format(self.name, self.value)


@dataclass(order=True, frozen=True)
class ASPBasicLiteral(ASPLiteral):
    sign: ASPSign = ASPSign.NoSign
    atom: ASPAtom = field(default_factory=ASPAtom)

    @property
    def is_pos(self) -> bool:
        return self.sign is ASPSign.NoSign

    @property
    def is_neg(self) -> bool:
        return self.sign is ASPSign.Negation

    @property
    def signature(self) -> str:
        return self.atom.signature

    def __str__(self):
        if self.sign is ASPSign.NoSign:
            return "{}".format(self.atom)
        else:
            return "{} {}".format(self.sign, self.atom)

    def __neg__(self):
        return ASPBasicLiteral(ASPSign((self.sign ^ 1) % 2), self.atom)

    def __abs__(self):
        return ASPBasicLiteral(ASPSign.NoSign, self.atom)

    def as_classical_atom(self):
        return ClassicalAtom(str(self.atom.symbol))

    @staticmethod
    def make_literal(name: Optional[str], *arguments: Union[str, int, ASPFunction]):
        function_arguments = []
        for arg_ in arguments:
            if isinstance(arg_, str):
                arg = ASPFunction(arg_)
            elif isinstance(arg_, int):
                arg = ASPTerm(ASPIntegerConstant(arg_))
            else:
                arg = arg_
            function_arguments.append(arg)
        return ASPBasicLiteral(atom=ASPAtom(ASPFunction(name=name, arguments=tuple(function_arguments))))


@dataclass(order=True, frozen=True)
class ASPRule(abc.ABC):
    head: Optional[ASPHeadClauseElement] = field(default=None)
    body: Optional[Sequence[ASPClauseElement]] = field(default=None)

    @property
    @abc.abstractmethod
    def head_signature(self) -> str:
        raise NotImplementedError

    @staticmethod
    def fmt_body(body: Sequence[ASPClauseElement]):
        return ', '.join(map(str, body))


@dataclass(order=True, frozen=True)
class ASPNormalRule(ASPRule):
    head: ASPBasicLiteral = field(default_factory=ASPBasicLiteral)
    body: Sequence[ASPClauseElement] = field(default_factory=tuple)

    @property
    def head_signature(self) -> str:
        return self.head.signature

    def __str__(self):
        if self.body:
            return "{} :- {}.".format(self.head, ASPRule.fmt_body(self.body))
        else:
            return "{}.".format(self.head)


@dataclass(order=True, frozen=True)
class ASPIntegrityConstraint(ASPRule):
    body: Sequence[ASPClauseElement] = field(default_factory=tuple)
    head: bool = field(default=False, init=False)

    @property
    def head_signature(self) -> str:
        return '#false/0.'

    def __str__(self):
        if self.body:
            return ":- {}.".format(ASPRule.fmt_body(self.body))
        else:
            return ":-."


@dataclass(frozen=True, order=True)
class ClassicalAtom:
    symbol: str

    @property
    def is_complement(self) -> bool:
        return self.symbol.startswith('-')

    def __neg__(self):
        if self.is_complement:
            return ClassicalAtom(self.symbol[1:])
        else:
            return ClassicalAtom('-{}'.format(self.symbol))

    def __abs__(self):
        if self.is_complement:
            return -self
        return self

    def __str__(self):
        return self.symbol


ClassicalAlphabet = Set[ClassicalAtom]
ClassicalValuation = Mapping[ClassicalAtom, bool]


@dataclass(frozen=True, order=True)
class ClassicalLiteral:
    atom: ClassicalAtom
    sign: bool = field(default=True)

    def __str__(self):
        sign_str = ""
        if not self.sign:
            sign_str = "¬"
        return "{}{}".format(sign_str, self.atom)

    def __repr__(self):
        return str(self)

    def __neg__(self):
        return ClassicalLiteral(self.atom, not self.sign)

    def __and__(self, other):
        left = ClassicalFormula(self)
        right = other
        if isinstance(other, ClassicalLiteral):
            right = ClassicalFormula(right)
        return ClassicalFormula(left, ClassicalConnective.And, right)

    def __or__(self, other):
        left = ClassicalFormula(self)
        right = other
        if isinstance(other, ClassicalLiteral):
            right = ClassicalFormula(right)
        return ClassicalFormula(left, ClassicalConnective.Or, right)

    def __rshift__(self, other):
        left = ClassicalFormula(self)
        right = other
        if isinstance(other, ClassicalLiteral):
            right = ClassicalFormula(right)
        return ClassicalFormula(left, ClassicalConnective.Implies, right)


@dataclass(frozen=True, order=True)
class ClassicalTop(ClassicalLiteral):
    atom: ClassicalAtom = field(default=ClassicalAtom('⊤'), init=False)
    sign: bool = field(default=True, init=False)

    def __str__(self):
        return str(self.atom)

    def __repr__(self):
        return str(self)

    def __neg__(self):
        return ClassicalBot()

    def __and__(self, other):
        if isinstance(other, ClassicalLiteral):
            return ClassicalFormula(other)
        return other

    def __or__(self, other):
        return ClassicalFormula(ClassicalTop())


@dataclass(frozen=True, order=True)
class ClassicalBot(ClassicalLiteral):
    atom: ClassicalAtom = field(default=ClassicalAtom('⊥'), init=False)
    sign: bool = field(default=False, init=False)

    def __neg__(self):
        return ClassicalTop()

    def __str__(self):
        return str(self.atom)

    def __and__(self, other):
        return ClassicalFormula(ClassicalBot())

    def __or__(self, other):
        if isinstance(other, ClassicalLiteral):
            return ClassicalFormula(other)
        return other


class ClassicalConnective(IntEnum):
    And = 0
    Or = 1
    Implies = 2

    def __str__(self):
        if self is ClassicalConnective.And:
            return "∧"
        elif self is ClassicalConnective.Or:
            return "∨"
        elif self is ClassicalConnective.Implies:
            return "→"
        else:
            assert False, "Unhandled Connective.__str__: {} = {}".format(self.name, self.value)

    def evaluate(self, left: bool, right: bool):
        if self is ClassicalConnective.And:
            return left and right
        elif self is ClassicalConnective.Or:
            return left or right
        elif self is ClassicalConnective.Implies:
            return not left or right
        else:
            assert False, "Unhandled Connective.evaluate: {} = {}".format(self.name, self.value)


ForwardClassicalFormula = TypeVar('ForwardClassicalFormula', bound='ClassicalFormula')


@dataclass(frozen=True, order=True)
class ClassicalFormula:
    left: Union[ForwardClassicalFormula, ClassicalLiteral]
    connective: Optional[ClassicalConnective] = field(default=None)
    right: Union[ForwardClassicalFormula, None] = field(default=None)

    def __str__(self):
        left_str = str(self.left)
        connective_str = ""
        if self.connective is not None:
            connective_str = " {}".format(self.connective)
            if isinstance(self.left,
                          ClassicalFormula) and self.left.connective is not None and self.left.connective > self.connective:
                left_str = "({})".format(left_str)
        right_str = ""
        if self.right is not None:
            if self.right.left == ClassicalBot() and self.right.right is None and self.connective is ClassicalConnective.Implies:
                left_str = "¬({})".format(left_str)
                connective_str = ""
            else:
                right_str = " {}".format(self.right)
            if isinstance(self.right,
                          ClassicalFormula) and self.right.connective is not None and self.right.connective > self.connective:
                left_str = "({})".format(left_str)
        return "{}{}{}".format(left_str, connective_str, right_str)

    def __repr__(self):
        return str(self)

    def evaluate(self, valuation: Optional[ClassicalValuation] = None) -> bool:
        if isinstance(self.left, ClassicalLiteral):
            value_left = self.__evaluate_literal(self.left, valuation)
        else:
            assert isinstance(self.left, ClassicalFormula), "Unknown type for Formula.left. {}: {}".format(
                type(self.left).__name__, self.left)
            value_left = self.left.evaluate(valuation)
        if self.connective is not None and self.right is None:
            raise TypeError("Formula.connective present, despite Formula.right missing.")
        elif self.connective is None and self.right is not None:
            raise TypeError("Formula.connective missing, despite Formula.right present.")

        if self.connective is None and self.right is None:
            return value_left
        else:
            assert isinstance(self.right, ClassicalFormula), "Unknown type for Formula.right. {}: {}".format(
                type(self.right).__name__, self.right)
            value_right = self.right.evaluate(valuation)

            return self.connective.evaluate(value_left, value_right)

    def __evaluate_literal(self, literal: ClassicalLiteral, valuation: Optional[ClassicalValuation] = None) -> bool:
        if isinstance(literal, ClassicalTop) or isinstance(literal, ClassicalBot):
            return literal.sign
        else:
            # get assigned truth value of atom (per default false) and flip the result if negated
            return valuation is not None and bool(valuation.get(literal.atom, False) ^ (not literal.sign))

    def set_to_bot(self, *atoms: ClassicalAtom) -> ForwardClassicalFormula:
        if isinstance(self.left, ClassicalLiteral):
            assert self.connective is None
            assert self.right is None
            if self.left.atom in atoms:
                if self.left.sign:
                    return ClassicalFormula(ClassicalBot())
                else:
                    return ClassicalFormula(ClassicalTop())
            else:
                return self
        else:
            left = self.left.set_to_bot(*atoms)
            right = self.right
            if right is not None:
                right = self.right.set_to_bot(*atoms)
            return ClassicalFormula(left, self.connective, right)

    @property
    def literals(self) -> Set[ClassicalLiteral]:
        literals = set()
        if isinstance(self.left, ClassicalLiteral):
            if not isinstance(self.left, ClassicalTop) and not isinstance(self.left, ClassicalBot):
                literals.add(self.left)
        else:
            assert isinstance(self.left, ClassicalFormula), "Unknown type for Formula.right. {}: {}".format(
                type(self.left).__name__, self.left)
            literals.update(self.left.literals)
        if self.right is not None:
            assert isinstance(self.right, ClassicalFormula), "Unknown type for Formula.right. {}: {}".format(
                type(self.right).__name__, self.right)
            literals.update(self.right.literals)
        return literals

    @property
    def atoms(self) -> Set[ClassicalAtom]:
        return {literal.atom for literal in self.literals}

    def __neg__(self):
        if self.connective is not None and self.right is None:
            raise TypeError("Formula.connective present, despite Formula.right missing.")
        elif self.connective is None and self.right is not None:
            raise TypeError("Formula.connective missing, despite Formula.right present.")

        if self.connective is None and self.right is None:
            return ClassicalFormula(-self.left)
        elif self.connective is ClassicalConnective.And:
            return ClassicalFormula(-self.left, ClassicalConnective.Or, -self.right)
        elif self.connective is ClassicalConnective.Or:
            return ClassicalFormula(-self.left, ClassicalConnective.And, -self.right)
        elif self.connective is ClassicalConnective.Implies:
            if self.right.left == ClassicalBot() and self.right.right is None:
                return self.left
            return ClassicalFormula(self, ClassicalConnective.Implies, ClassicalFormula(ClassicalBot()))
        else:
            assert False, "Unknown Formula.connective. {} = {}.".format(self.connective.name, self.connective.value)

    @property
    def is_top(self) -> bool:
        return self.right is None and isinstance(self.left, ClassicalTop)

    @property
    def is_bot(self) -> bool:
        return self.right is None and isinstance(self.left, ClassicalBot)

    def __and__(self, other):
        left = self
        right = other
        if isinstance(other, ClassicalLiteral):
            right = ClassicalFormula(right)
        if left.is_top:
            return right
        elif right.is_top:
            return left
        if left.is_bot:
            return left
        elif right.is_bot:
            return right
        return ClassicalFormula(left, ClassicalConnective.And, right)

    def __or__(self, other):
        left = self
        right = other
        if isinstance(other, ClassicalLiteral):
            right = ClassicalFormula(right)
        if left.is_top:
            return left
        elif right.is_top:
            return right
        if left.is_bot:
            return right
        elif right.is_bot:
            return left
        return ClassicalFormula(left, ClassicalConnective.Or, right)

    def __rshift__(self, other):
        left = self
        right = other
        if isinstance(other, ClassicalLiteral):
            right = ClassicalFormula(right)
        return ClassicalFormula(left, ClassicalConnective.Implies, right)

    def __call__(self, valuation: Optional[ClassicalValuation] = None) -> bool:
        return self.evaluate(valuation)


def all_valuations(alphabet: ClassicalAlphabet, complete: bool = False) -> Iterator[ClassicalValuation]:
    subsets = powerset(alphabet)
    for subset in subsets:
        valuation = defaultdict(lambda: False)
        for atom in subset:
            valuation[atom] = True
        if complete:
            for atom in alphabet:
                if atom not in subset:
                    valuation[atom] = False
        yield valuation


def models(formulas: Set[ClassicalFormula], alphabet: Optional[ClassicalAlphabet] = None) -> Iterator[
    ClassicalValuation]:
    if alphabet is None:
        alphabet = {atom for formula in formulas for atom in formula.atoms}
    for valuation in all_valuations(alphabet):
        if all(formula.evaluate(valuation) for formula in formulas):
            yield valuation


def sat(formulas: Set[ClassicalFormula], alphabet: Optional[ClassicalAlphabet] = None) -> bool:
    model = next(models(formulas, alphabet), None)
    return model is not None


def unsat(formulas: Set[ClassicalFormula], alphabet: Optional[ClassicalAlphabet] = None) -> bool:
    return not sat(formulas, alphabet)


def entails(formulas: Set[ClassicalFormula], formula: ClassicalFormula) -> bool:
    return unsat(formulas | {-formula})


def valid(formulas: Set[ClassicalFormula], alphabet: Optional[ClassicalAlphabet] = None) -> bool:
    if alphabet is None:
        alphabet = {atom for formula in formulas for atom in formula.atoms}
    for valuation in all_valuations(alphabet):
        if any(not formula.evaluate(valuation) for formula in formulas):
            return False
    return True


def empty_conditions(*args, **kwargs):
    return defaultdict(lambda: ClassicalFormula(ClassicalBot()))


@dataclass
class ADF:
    statements: Set[ClassicalAtom] = field(default_factory=set)
    conditions: Mapping[ClassicalAtom, ClassicalFormula] = field(default_factory=empty_conditions)
    rule_atoms: Set[ClassicalAtom] = field(default_factory=set)

    def is_fact(self, atom: ClassicalAtom) -> bool:
        return atom in self.conditions and any(
            condition in self.conditions and self.conditions[condition].is_top for condition in
            self.conditions[atom].atoms)

    def is_non_factual(self, atom: ClassicalAtom) -> bool:
        return self.conditions.get(atom, ClassicalFormula(ClassicalBot())).is_bot

    def __str__(self):
        return "{}{}{} <{}>".format('{', ' '.join(map(str, self.statements)), '}',
                                    ', '.join(map(lambda i: '{}: {}'.format(i[0], i[1]), self.conditions.items())))

    def __repr__(self):
        return str(self)


def asp_to_adf(*rules: ASPRule):
    statements = set()
    conditions = empty_conditions()
    rule_atoms = set()
    for i, rule in enumerate(rules):
        r = ClassicalLiteral(ClassicalAtom('r{}'.format(i + 1)))
        rule_atoms.add(r.atom)
        bs = set(
            ClassicalLiteral(ClassicalAtom(str(literal.atom.symbol)), sign=literal.is_pos) for literal in rule.body)
        statements.add(r.atom)
        statements.update(b.atom for b in bs)
        if isinstance(rule, ASPNormalRule):
            h = ClassicalLiteral(ClassicalAtom(str(rule.head.atom.symbol)))
            statements.add(h.atom)

            formula = conditions[h.atom]
            formula = formula | r
            conditions[h.atom] = formula
            formula = ClassicalFormula(ClassicalTop())

        elif isinstance(rule, ASPIntegrityConstraint):
            formula = -ClassicalFormula(r)
        else:
            assert False, "Unknown ASPRule {} with type {}.".format(rule, type(rule).__name__)

        for b in bs:
            formula = formula & b
        conditions[r.atom] = formula

    complements = set()
    for complement in statements:
        if complement.is_complement:
            for statement in statements:
                if statement == -complement:
                    cmp = ClassicalLiteral(ClassicalAtom('cmp({})'.format(statement.symbol)))
                    cmp_condition = -cmp & ClassicalLiteral(statement) & ClassicalLiteral(complement)
                    complements.add(cmp.atom)
                    conditions[cmp.atom] = cmp_condition

    statements.update(complements)

    return ADF(statements, conditions, rule_atoms)


def answer_set_to_valuation(answer_set: Iterable[ASPTopLevelSymbol]) -> ClassicalValuation:
    valuation = defaultdict(lambda: False)
    for elem in answer_set:
        atom = ClassicalAtom(str(elem))
        valuation[atom] = True
    return valuation


def valuation_to_extension(valuation: ClassicalValuation) -> Set[ClassicalAtom]:
    extension = set()
    for atom, truthvalue in valuation.items():
        if truthvalue:
            extension.add(atom)
    return extension


def extension_to_valuation(extension: Set[ClassicalAtom]) -> ClassicalValuation:
    valuation = defaultdict(lambda: False)
    for atom in extension:
        valuation[atom] = True
    return valuation

# %%
PDE = Tuple[ClassicalAtom, Set[ClassicalAtom], Set[ClassicalAtom], Sequence[ClassicalAtom]]


def fmt_pde(pde: PDE) -> str:
    return "({}, {}{}{}, {}{}{}, [{}])".format(pde[0], '{', ','.join(map(str, pde[1])), '}', '{',
                                               ','.join(map(str, pde[2])), '}', ','.join(map(str, pde[3])))


def print_pde(pde: PDE):
    print(fmt_pde(pde))


def get_pdes(adf: ADF,
             e: ClassicalAtom,
             extension: Set[ClassicalAtom],
             sequence: Optional[MutableSequence[ClassicalAtom]] = None,
             facts: Optional[Set[ClassicalAtom]] = None,
             blocking: Optional[Set[ClassicalAtom]] = None) -> Sequence[PDE]:
    if facts is None:
        facts = set()
    if blocking is None:
        blocking = set()
    if sequence is None:
        sequence = []

    sequence.insert(0, e)

    conditions = set(adf.conditions[e].atoms)

    pdes = []

    for condition in conditions:
        if len(conditions) > 1:
            facts_ = deepcopy(facts)
            blocking_ = deepcopy(blocking)
            sequence_ = deepcopy(sequence)
        else:
            facts_ = facts
            blocking_ = blocking
            sequence_ = sequence
        sequence_.insert(0, condition)
        if adf.is_fact(e):
            facts_.add(e)
            pdes.append((e, facts_, blocking_, sequence_))
            return pdes

        subcondition = adf.conditions[condition]
        literals = set(subcondition.literals)
        branch_pdes = [(e, facts_, blocking_, sequence_)]
        subpdes = None
        for literal in literals:
            if literal.sign is False:
                blocking_.add(literal.atom)
                continue
            subpdes = []
            for branch in branch_pdes:
                _, facts_, blocking_, sequence_ = branch
                subpdes.extend(get_pdes(adf, literal.atom, extension, sequence_, facts_, blocking_))
            branch_pdes = subpdes
        if subpdes is not None and subpdes:
            for subpde in subpdes:
                _, facts_, blocking_, sequence_ = subpde
                pdes.append((e, facts_, blocking_, sequence_))
        else:
            pdes.append((e, facts_, blocking_, sequence_))

    return pdes

# %%
CompactPDE = Tuple[ClassicalAtom, FrozenSet[ClassicalAtom], FrozenSet[ClassicalAtom], FrozenSet[ClassicalAtom]]


def fmt_compact_pde(pde: CompactPDE) -> str:
    return "({}, {}{}{}, {}{}{}, {}{}{})".format(pde[0], '{', ','.join(map(str, sorted(pde[1]))), '}', '{',
                                                 ','.join(map(str, sorted(pde[2]))), '}', '{',
                                                 ','.join(map(str, sorted(pde[3]))), '}')


def print_compact_pde(pde: CompactPDE):
    print(fmt_compact_pde(pde))


ForwardASLExplanationGraph = TypeVar('ForwardASLExplanationGraph', bound='ASLExplanationGraph')


@dataclass
class ASLJustificationTree:
    adf: ADF
    extension: Set[ClassicalAtom]
    pde: CompactPDE
    proof: bool = field(default=False)
    children: Optional[MutableSequence[ForwardASLExplanationGraph]] = field(default=None)

    @property
    def is_expanded(self) -> bool:
        return self.children is not None

    def expand(self):
        raise NotImplementedError

    def expand_recursively(self, depth=None):
        if depth is not None and depth <= 0:
            return
        self.expand()
        for child in self.children:
            child.expand_recursively(depth=None if depth is None else depth - 1)

    def fmt(self, indent=0, root=True):
        fmt = ""
        if root:
            fmt += '*\n|'
        for i in range(indent):
            fmt += '|  '
        if indent > 0:
            fmt += '\n'
            for i in range(indent - 1):
                fmt += '|  '
            fmt += '|__'

        fmt += '__' + str(self)
        if self.is_expanded:
            for child in self.children:
                fmt += '\n' + child.fmt(indent=indent + 1, root=False)
        return fmt

    def pretty_print(self):
        print(self.fmt())

    def __str__(self):
        return "<{},{}>".format(fmt_compact_pde(self.pde), '+' if self.proof else '-')


@dataclass
class ASLRefutation(ASLJustificationTree):
    proof: bool = field(default=False, init=False)

    def expand(self):
        if self.is_expanded:
            return
        children = []

        for block in self.pde[2]:
            child_pdes = {compress(self.adf, pde) for pde in get_pdes(self.adf, block, self.extension)}
            assert len(child_pdes) == 1
            child = ASLProof(adf=self.adf,
                             extension=self.extension,
                             pde=compress(self.adf, next(iter(child_pdes))))
            children.append(child)
        self.children = children


@dataclass
class ASLProof(ASLJustificationTree):
    proof: bool = field(default=True, init=False)

    def expand(self, prefer: Optional[ClassicalAtom] = None):
        if self.is_expanded:
            return
        children = []

        if not self.adf.is_fact(self.pde[0]) and frozenset((-self.pde[0],)) != self.pde[2]:
            for block in self.pde[2]:
                if self.adf.is_non_factual(block):
                    continue
                child_pdes = {compress(self.adf, pde) for pde in get_pdes(self.adf, block, self.extension)}

                for pde in child_pdes:
                    child = ASLRefutation(adf=self.adf, extension=self.extension, pde=pde)
                    children.append(child)

        self.children = children


def compress(adf: ADF, pde: PDE) -> CompactPDE:
    literal, facts, blocking, sequence = pde
    return literal, frozenset(facts), frozenset(blocking), frozenset(
        elem for elem in sequence if elem in adf.rule_atoms)


def less_specific(pde1: CompactPDE, pde2: CompactPDE) -> bool:
    return pde1[0] == pde2[0] and (
            (pde1[1] >= pde2[1] and pde1[2] > pde2[2]) or (pde1[1] > pde2[1] and pde1[2] >= pde2[2]))


def more_specific(pde1: CompactPDE, pde2: CompactPDE) -> bool:
    return pde1[0] == pde2[0] and (
            (pde1[1] <= pde2[1] and pde1[2] < pde2[2]) or (pde1[1] < pde2[1] and pde1[2] <= pde2[2]))


def compare_cde(pde1: CompactPDE, pde2: CompactPDE) -> int:
    if less_specific(pde1, pde2) and more_specific(pde2, pde1):
        return -1
    elif less_specific(pde2, pde1) and more_specific(pde1, pde2):
        return 1
    else:
        return 0


def make_program(*rules: ASPRule):
    return '\n'.join(map(str, rules))

# %%
def is_model(adf: ADF,
             extension: Set[ClassicalAtom],
             alphabet: Optional[ClassicalAlphabet] = None,
             valuation: Optional[ClassicalValuation] = None):
    if alphabet is None:
        alphabet = adf.statements
    if valuation is None:
        valuation = extension_to_valuation(extension)
    return all((atom in extension) == (adf.conditions[atom](valuation)) for atom in alphabet)

# %%
def adf_models(adf: ADF) -> Iterator[FrozenSet[ClassicalAtom]]:
    alphabet = adf.statements
    for extension_ in powerset(alphabet):
        extension = frozenset(extension_)
        valuation = extension_to_valuation(extension)
        if is_model(adf, extension, alphabet, valuation):
            yield extension

# %%
def gamma(adf: ADF, A: Optional[Set[ClassicalAtom]] = None, R: Optional[Set[ClassicalAtom]] = None):
    if A is None:
        A = set()
    if R is None:
        R = set()
    S = adf.statements
    acc = {r for r in S if all(
        adf.conditions[r](extension_to_valuation(A | set(S_))) for S_ in powerset(S - R))}
    reb = {r for r in S if
           all(not adf.conditions[r](extension_to_valuation(A | set(S_))) for S_ in powerset(S - R))}
    return acc, reb

# %%
def maybe_grounded_model(adf: ADF,
                         A: Set[ClassicalAtom],
                         R: Set[ClassicalAtom]):
    S = adf.statements
    acc = {r for r in S if
           all(adf.conditions[r](extension_to_valuation(A | set(S_))) for S_ in powerset(S - R))}
    if A != acc:
        return False
    reb = {r for r in S if
           all(not adf.conditions[r](extension_to_valuation(A | set(S_))) for S_ in powerset(S - R))}
    return R == reb

# %%
def reduct(adf: ADF, model: Set[ClassicalAtom]) -> ADF:
    conditions = {}
    not_model = adf.statements - model
    for atom,condition in adf.conditions.items():
        conditions[atom] = condition.set_to_bot(*not_model)
    return ADF(model, conditions, adf.rule_atoms & model)

# %%
a = ASPBasicLiteral.make_literal('a')
b = ASPBasicLiteral.make_literal('b')
c = ASPBasicLiteral.make_literal('c')
nc = ASPBasicLiteral.make_literal('-c')

r1 = ASPNormalRule(a, (b, c))
r2 = ASPNormalRule(b, (c,))
r3 = ASPNormalRule(c)


rs = (r1, r2, r3)

prg = make_program(*rs)
print(prg)
# Out:
# a :- b, c.
# b :- c.
# c.

# %%
answer_sets = tuple(asp_evaluate(prg, report=True))
# Out:
# Answer 1: { a b c }
# SAT 1

# %%
val = answer_set_to_valuation(answer_sets[0])
ext = valuation_to_extension(val)

# %%
adf = asp_to_adf(*rs)
print(adf)
# Out:
# {r1 r3 c a b r2} <a: r1, r1: c ∧ b, b: r2, r2: c, c: r3, r3: ⊤>

# %%
for model in adf_models(adf):
    print('{', ','.join(map(str, sorted(model))), '}')
    print('is grounded model:', maybe_grounded_model(adf, model, adf.statements-model))
    red = reduct(adf, model)
    print('reduct:', red)
    print('is grounded model of reduct:', maybe_grounded_model(red, model, set()))
# Out:
# { a,b,c,r1,r2,r3 }
# is grounded model: True
# reduct: {r1 r3 c a b r2} <a: r1, r1: c ∧ b, b: r2, r2: c, c: r3, r3: ⊤>
# is grounded model of reduct: True

# %%
A, R = None, None

# %%
A, R = gamma(adf, A, R)
print(','.join(map(str, A)))
print(','.join(map(str, R)))
# Out:
# r3

# %%
A = {a.as_classical_atom(), b.as_classical_atom(), ClassicalAtom('r1'), ClassicalAtom('r2')}
print(','.join(map(str, A)))
print(','.join(map(str, R)))
# Out:
# r1,a,b,r2

# %%
for assignment_ in powerset(adf.statements):
    print('{', ','.join(map(str, sorted(assignment_))), '}')
    extension = set(assignment_)
    print('                   model:', is_model(adf, extension))
    print('          grounded model:', maybe_grounded_model(adf, extension, adf.statements - extension))
    red = reduct(adf, extension)
    print('                  reduct:', red)
    print('Grounded model of reduct:', maybe_grounded_model(red, extension, set()))
# Out:
# {  }
#                    model: False
#           grounded model: False
#                   reduct: {} <a: ⊥, r1: ⊥ ∧ ⊥, b: ⊥, r2: ⊥, c: ⊥, r3: ⊤>
# Grounded model of reduct: True
# { r1 }
#                    model: False
#           grounded model: False
#                   reduct: {r1} <a: r1, r1: ⊥ ∧ ⊥, b: ⊥, r2: ⊥, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3} <a: ⊥, r1: ⊥ ∧ ⊥, b: ⊥, r2: ⊥, c: r3, r3: ⊤>
# Grounded model of reduct: True
# { c }
#                    model: False
#           grounded model: False
#                   reduct: {c} <a: ⊥, r1: c ∧ ⊥, b: ⊥, r2: c, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { a }
#                    model: False
#           grounded model: False
#                   reduct: {a} <a: ⊥, r1: ⊥ ∧ ⊥, b: ⊥, r2: ⊥, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { b }
#                    model: False
#           grounded model: False
#                   reduct: {b} <a: ⊥, r1: ⊥ ∧ b, b: ⊥, r2: ⊥, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { r2 }
#                    model: False
#           grounded model: False
#                   reduct: {r2} <a: ⊥, r1: ⊥ ∧ ⊥, b: r2, r2: ⊥, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { r1,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r3} <a: r1, r1: ⊥ ∧ ⊥, b: ⊥, r2: ⊥, c: r3, r3: ⊤>
# Grounded model of reduct: False
# { c,r1 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 c} <a: r1, r1: c ∧ ⊥, b: ⊥, r2: c, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { a,r1 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 a} <a: r1, r1: ⊥ ∧ ⊥, b: ⊥, r2: ⊥, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { b,r1 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 b} <a: r1, r1: ⊥ ∧ b, b: ⊥, r2: ⊥, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { r1,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r2} <a: r1, r1: ⊥ ∧ ⊥, b: r2, r2: ⊥, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { c,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 c} <a: ⊥, r1: c ∧ ⊥, b: ⊥, r2: c, c: r3, r3: ⊤>
# Grounded model of reduct: True
# { a,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 a} <a: ⊥, r1: ⊥ ∧ ⊥, b: ⊥, r2: ⊥, c: r3, r3: ⊤>
# Grounded model of reduct: False
# { b,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 b} <a: ⊥, r1: ⊥ ∧ b, b: ⊥, r2: ⊥, c: r3, r3: ⊤>
# Grounded model of reduct: False
# { r2,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 r2} <a: ⊥, r1: ⊥ ∧ ⊥, b: r2, r2: ⊥, c: r3, r3: ⊤>
# Grounded model of reduct: False
# { a,c }
#                    model: False
#           grounded model: False
#                   reduct: {a c} <a: ⊥, r1: c ∧ ⊥, b: ⊥, r2: c, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { b,c }
#                    model: False
#           grounded model: False
#                   reduct: {b c} <a: ⊥, r1: c ∧ b, b: ⊥, r2: c, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { c,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {c r2} <a: ⊥, r1: c ∧ ⊥, b: r2, r2: c, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { a,b }
#                    model: False
#           grounded model: False
#                   reduct: {a b} <a: ⊥, r1: ⊥ ∧ b, b: ⊥, r2: ⊥, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { a,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {a r2} <a: ⊥, r1: ⊥ ∧ ⊥, b: r2, r2: ⊥, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { b,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {b r2} <a: ⊥, r1: ⊥ ∧ b, b: r2, r2: ⊥, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { c,r1,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r3 c} <a: r1, r1: c ∧ ⊥, b: ⊥, r2: c, c: r3, r3: ⊤>
# Grounded model of reduct: False
# { a,r1,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 a r3} <a: r1, r1: ⊥ ∧ ⊥, b: ⊥, r2: ⊥, c: r3, r3: ⊤>
# Grounded model of reduct: False
# { b,r1,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r3 b} <a: r1, r1: ⊥ ∧ b, b: ⊥, r2: ⊥, c: r3, r3: ⊤>
# Grounded model of reduct: False
# { r1,r2,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r3 r2} <a: r1, r1: ⊥ ∧ ⊥, b: r2, r2: ⊥, c: r3, r3: ⊤>
# Grounded model of reduct: False
# { a,c,r1 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 a c} <a: r1, r1: c ∧ ⊥, b: ⊥, r2: c, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { b,c,r1 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 b c} <a: r1, r1: c ∧ b, b: ⊥, r2: c, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { c,r1,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 c r2} <a: r1, r1: c ∧ ⊥, b: r2, r2: c, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { a,b,r1 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 a b} <a: r1, r1: ⊥ ∧ b, b: ⊥, r2: ⊥, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { a,r1,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 a r2} <a: r1, r1: ⊥ ∧ ⊥, b: r2, r2: ⊥, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { b,r1,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 b r2} <a: r1, r1: ⊥ ∧ b, b: r2, r2: ⊥, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { a,c,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 a c} <a: ⊥, r1: c ∧ ⊥, b: ⊥, r2: c, c: r3, r3: ⊤>
# Grounded model of reduct: False
# { b,c,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 b c} <a: ⊥, r1: c ∧ b, b: ⊥, r2: c, c: r3, r3: ⊤>
# Grounded model of reduct: False
# { c,r2,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 c r2} <a: ⊥, r1: c ∧ ⊥, b: r2, r2: c, c: r3, r3: ⊤>
# Grounded model of reduct: True
# { a,b,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 a b} <a: ⊥, r1: ⊥ ∧ b, b: ⊥, r2: ⊥, c: r3, r3: ⊤>
# Grounded model of reduct: False
# { a,r2,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 a r2} <a: ⊥, r1: ⊥ ∧ ⊥, b: r2, r2: ⊥, c: r3, r3: ⊤>
# Grounded model of reduct: False
# { b,r2,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 b r2} <a: ⊥, r1: ⊥ ∧ b, b: r2, r2: ⊥, c: r3, r3: ⊤>
# Grounded model of reduct: False
# { a,b,c }
#                    model: False
#           grounded model: False
#                   reduct: {a b c} <a: ⊥, r1: c ∧ b, b: ⊥, r2: c, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { a,c,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {a c r2} <a: ⊥, r1: c ∧ ⊥, b: r2, r2: c, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { b,c,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {b c r2} <a: ⊥, r1: c ∧ b, b: r2, r2: c, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { a,b,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {a b r2} <a: ⊥, r1: ⊥ ∧ b, b: r2, r2: ⊥, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { a,c,r1,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 a r3 c} <a: r1, r1: c ∧ ⊥, b: ⊥, r2: c, c: r3, r3: ⊤>
# Grounded model of reduct: False
# { b,c,r1,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r3 b c} <a: r1, r1: c ∧ b, b: ⊥, r2: c, c: r3, r3: ⊤>
# Grounded model of reduct: False
# { c,r1,r2,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r3 c r2} <a: r1, r1: c ∧ ⊥, b: r2, r2: c, c: r3, r3: ⊤>
# Grounded model of reduct: False
# { a,b,r1,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 a r3 b} <a: r1, r1: ⊥ ∧ b, b: ⊥, r2: ⊥, c: r3, r3: ⊤>
# Grounded model of reduct: False
# { a,r1,r2,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 a r3 r2} <a: r1, r1: ⊥ ∧ ⊥, b: r2, r2: ⊥, c: r3, r3: ⊤>
# Grounded model of reduct: False
# { b,r1,r2,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r3 b r2} <a: r1, r1: ⊥ ∧ b, b: r2, r2: ⊥, c: r3, r3: ⊤>
# Grounded model of reduct: False
# { a,b,c,r1 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 a b c} <a: r1, r1: c ∧ b, b: ⊥, r2: c, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { a,c,r1,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 a c r2} <a: r1, r1: c ∧ ⊥, b: r2, r2: c, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { b,c,r1,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 b c r2} <a: r1, r1: c ∧ b, b: r2, r2: c, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { a,b,r1,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 a b r2} <a: r1, r1: ⊥ ∧ b, b: r2, r2: ⊥, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { a,b,c,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 a b c} <a: ⊥, r1: c ∧ b, b: ⊥, r2: c, c: r3, r3: ⊤>
# Grounded model of reduct: False
# { a,c,r2,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 a c r2} <a: ⊥, r1: c ∧ ⊥, b: r2, r2: c, c: r3, r3: ⊤>
# Grounded model of reduct: False
# { b,c,r2,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 b c r2} <a: ⊥, r1: c ∧ b, b: r2, r2: c, c: r3, r3: ⊤>
# Grounded model of reduct: True
# { a,b,r2,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 a b r2} <a: ⊥, r1: ⊥ ∧ b, b: r2, r2: ⊥, c: r3, r3: ⊤>
# Grounded model of reduct: False
# { a,b,c,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {a b c r2} <a: ⊥, r1: c ∧ b, b: r2, r2: c, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { a,b,c,r1,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r3 c a b} <a: r1, r1: c ∧ b, b: ⊥, r2: c, c: r3, r3: ⊤>
# Grounded model of reduct: False
# { a,c,r1,r2,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r3 c a r2} <a: r1, r1: c ∧ ⊥, b: r2, r2: c, c: r3, r3: ⊤>
# Grounded model of reduct: False
# { b,c,r1,r2,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r3 c b r2} <a: r1, r1: c ∧ b, b: r2, r2: c, c: r3, r3: ⊤>
# Grounded model of reduct: True
# { a,b,r1,r2,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r3 a b r2} <a: r1, r1: ⊥ ∧ b, b: r2, r2: ⊥, c: r3, r3: ⊤>
# Grounded model of reduct: False
# { a,b,c,r1,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 c a b r2} <a: r1, r1: c ∧ b, b: r2, r2: c, c: ⊥, r3: ⊤>
# Grounded model of reduct: False
# { a,b,c,r2,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 c a b r2} <a: ⊥, r1: c ∧ b, b: r2, r2: c, c: r3, r3: ⊤>
# Grounded model of reduct: False
# { a,b,c,r1,r2,r3 }
#                    model: True
#           grounded model: True
#                   reduct: {r1 r3 c a b r2} <a: r1, r1: c ∧ b, b: r2, r2: c, c: r3, r3: ⊤>
# Grounded model of reduct: True

# %%
a = ASPBasicLiteral.make_literal('a')
b = ASPBasicLiteral.make_literal('b')
c = ASPBasicLiteral.make_literal('c')
nc =  ASPBasicLiteral.make_literal('-c')

r1 = ASPNormalRule(a, (b,))
r2 = ASPNormalRule(b, (a,))
r3 = ASPNormalRule(b, (c,))
r4 = ASPNormalRule(c, (-nc,))
r5 = ASPNormalRule(nc, (-c,))

rs = (r1, r2, r3, r4, r5)

prg = make_program(*rs)
print(prg)
# Out:
# a :- b.
# b :- a.
# b :- c.
# c :- not -c.
# -c :- not c.

# %%
answer_sets = tuple(asp_evaluate(prg, report=True))
# Out:
# Answer 1: { -c }
# Answer 2: { a b c }
# SAT 2

# %%
val = answer_set_to_valuation(answer_sets[0])
ext = valuation_to_extension(val)

# %%
adf = asp_to_adf(*rs)
print(adf)
# Out:
# {-c r5 r4 r1 r3 c cmp(c) a b r2} <a: r1, r1: b, b: r2 ∨ r3, r2: a, r3: c, c: r4, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>

# %%
A, R = None, None

# %%
A, R = gamma(adf, A, R)
print(','.join(map(str, A)))
print(','.join(map(str, R)))

# %%
A = {a.as_classical_atom(), b.as_classical_atom(), nc.as_classical_atom(), ClassicalAtom('r1'), ClassicalAtom('r2'), ClassicalAtom('r5')}
R = adf.statements - A

# %%
for model in adf_models(adf):
    print('{', ','.join(map(str, sorted(model))), '}')
    print('is grounded model:', maybe_grounded_model(adf, model, adf.statements-model))
    red = reduct(adf, model)
    print('reduct:', red)
    print('is grounded model of reduct:', maybe_grounded_model(red, model, set()))
# Out:
# { -c,r5 }
# is grounded model: True
# reduct: {r5 -c} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# is grounded model of reduct: True
# { -c,a,b,r1,r2,r5 }
# is grounded model: True
# reduct: {r5 -c r1 a b r2} <a: r1, r1: b, b: r2 ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# is grounded model of reduct: True
# { a,b,c,r1,r2,r3,r4 }
# is grounded model: True
# reduct: {r1 r3 b c a r4 r2} <a: r1, r1: b, b: r2 ∨ r3, r2: a, r3: c, c: r4, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# is grounded model of reduct: True

# %%
for assignment_ in powerset(adf.statements):
    print('{', ','.join(map(str, sorted(assignment_))), '}')
    extension = set(assignment_)
    print('                   model:', is_model(adf, extension))
    print('          grounded model:', maybe_grounded_model(adf, extension, adf.statements - extension))
    red = reduct(adf, extension)
    print('                  reduct:', red)
    print('grounded model of reduct:', maybe_grounded_model(red, extension, set()))
# Out:
# {  }
#                    model: False
#           grounded model: False
#                   reduct: {} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: True
# { -c }
#                    model: False
#           grounded model: False
#                   reduct: {-c} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: True
# { r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r4} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: r4, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: True
# { r1 }
#                    model: False
#           grounded model: False
#                   reduct: {r1} <a: r1, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3} <a: ⊥, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { c }
#                    model: False
#           grounded model: False
#                   reduct: {c} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: c, c: ⊥, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { cmp(c) }
#                    model: False
#           grounded model: False
#                   reduct: {cmp(c)} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { a }
#                    model: False
#           grounded model: False
#                   reduct: {a} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { b }
#                    model: False
#           grounded model: False
#                   reduct: {b} <a: ⊥, r1: b, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { r2 }
#                    model: False
#           grounded model: False
#                   reduct: {r2} <a: ⊥, r1: ⊥, b: r2 ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { -c,r5 }
#                    model: True
#           grounded model: True
#                   reduct: {r5 -c} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: True
# { -c,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {-c r4} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: r4, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,r1 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 -c} <a: r1, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 -c} <a: ⊥, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,c }
#                    model: False
#           grounded model: False
#                   reduct: {-c c} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: c, c: ⊥, r4: ¬-c, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,cmp(c) }
#                    model: False
#           grounded model: False
#                   reduct: {-c cmp(c)} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,a }
#                    model: False
#           grounded model: False
#                   reduct: {a -c} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,b }
#                    model: False
#           grounded model: False
#                   reduct: {-c b} <a: ⊥, r1: b, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {-c r2} <a: ⊥, r1: ⊥, b: r2 ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: r4, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: True
# { r1,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r5} <a: r1, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { r3,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 r5} <a: ⊥, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { c,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 c} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: c, c: ⊥, r4: ⊤, -c: r5, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { cmp(c),r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 cmp(c)} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { a,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {a r5} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { b,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 b} <a: ⊥, r1: b, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { r2,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r2} <a: ⊥, r1: ⊥, b: r2 ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { r1,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r4} <a: r1, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: r4, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { r3,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 r4} <a: ⊥, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: r4, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { c,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r4 c} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: c, c: r4, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: True
# { cmp(c),r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r4 cmp(c)} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: r4, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { a,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {a r4} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: a, r3: ⊥, c: r4, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { b,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r4 b} <a: ⊥, r1: b, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: r4, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { r2,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r4 r2} <a: ⊥, r1: ⊥, b: r2 ∨ ⊥, r2: ⊥, r3: ⊥, c: r4, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { r1,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r3} <a: r1, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { c,r1 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 c} <a: r1, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: c, c: ⊥, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { cmp(c),r1 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 cmp(c)} <a: r1, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { a,r1 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 a} <a: r1, r1: ⊥, b: ⊥ ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { b,r1 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 b} <a: r1, r1: b, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { r1,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r2} <a: r1, r1: ⊥, b: r2 ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { c,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 c} <a: ⊥, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: c, c: ⊥, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { cmp(c),r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 cmp(c)} <a: ⊥, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { a,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 a} <a: ⊥, r1: ⊥, b: ⊥ ∨ r3, r2: a, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { b,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 b} <a: ⊥, r1: b, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { r2,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 r2} <a: ⊥, r1: ⊥, b: r2 ∨ r3, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { c,cmp(c) }
#                    model: False
#           grounded model: False
#                   reduct: {c cmp(c)} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: c, c: ⊥, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ ⊥>
# grounded model of reduct: False
# { a,c }
#                    model: False
#           grounded model: False
#                   reduct: {a c} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: a, r3: c, c: ⊥, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { b,c }
#                    model: False
#           grounded model: False
#                   reduct: {b c} <a: ⊥, r1: b, b: ⊥ ∨ ⊥, r2: ⊥, r3: c, c: ⊥, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { c,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {c r2} <a: ⊥, r1: ⊥, b: r2 ∨ ⊥, r2: ⊥, r3: c, c: ⊥, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { a,cmp(c) }
#                    model: False
#           grounded model: False
#                   reduct: {a cmp(c)} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { b,cmp(c) }
#                    model: False
#           grounded model: False
#                   reduct: {b cmp(c)} <a: ⊥, r1: b, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { cmp(c),r2 }
#                    model: False
#           grounded model: False
#                   reduct: {r2 cmp(c)} <a: ⊥, r1: ⊥, b: r2 ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { a,b }
#                    model: False
#           grounded model: False
#                   reduct: {a b} <a: ⊥, r1: b, b: ⊥ ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { a,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {a r2} <a: ⊥, r1: ⊥, b: r2 ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { b,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {b r2} <a: ⊥, r1: b, b: r2 ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { -c,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 -c r4} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: r4, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,r1,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 -c r1} <a: r1, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,r3,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r3 -c} <a: ⊥, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,c,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 -c c} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: c, c: ⊥, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ⊤ ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,cmp(c),r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 -c cmp(c)} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,a,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 a -c} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,b,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 -c b} <a: ⊥, r1: b, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,r2,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 -c r2} <a: ⊥, r1: ⊥, b: r2 ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,r1,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 -c r4} <a: r1, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: r4, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,r3,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 -c r4} <a: ⊥, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: r4, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,c,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {c -c r4} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: c, c: r4, r4: ¬-c, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,cmp(c),r4 }
#                    model: False
#           grounded model: False
#                   reduct: {-c r4 cmp(c)} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: r4, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,a,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {a -c r4} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: a, r3: ⊥, c: r4, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,b,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {-c b r4} <a: ⊥, r1: b, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: r4, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,r2,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {-c r4 r2} <a: ⊥, r1: ⊥, b: r2 ∨ ⊥, r2: ⊥, r3: ⊥, c: r4, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,r1,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r3 -c} <a: r1, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,c,r1 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 -c c} <a: r1, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: c, c: ⊥, r4: ¬-c, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,cmp(c),r1 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 -c cmp(c)} <a: r1, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,a,r1 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 a -c} <a: r1, r1: ⊥, b: ⊥ ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,b,r1 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 -c b} <a: r1, r1: b, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,r1,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 -c r2} <a: r1, r1: ⊥, b: r2 ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,c,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 -c c} <a: ⊥, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: c, c: ⊥, r4: ¬-c, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,cmp(c),r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 -c cmp(c)} <a: ⊥, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,a,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 a -c} <a: ⊥, r1: ⊥, b: ⊥ ∨ r3, r2: a, r3: ⊥, c: ⊥, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,b,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 -c b} <a: ⊥, r1: b, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,r2,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 -c r2} <a: ⊥, r1: ⊥, b: r2 ∨ r3, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,c,cmp(c) }
#                    model: False
#           grounded model: False
#                   reduct: {-c c cmp(c)} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: c, c: ⊥, r4: ¬-c, -c: ⊥, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,c }
#                    model: False
#           grounded model: False
#                   reduct: {a -c c} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: a, r3: c, c: ⊥, r4: ¬-c, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,b,c }
#                    model: False
#           grounded model: False
#                   reduct: {-c b c} <a: ⊥, r1: b, b: ⊥ ∨ ⊥, r2: ⊥, r3: c, c: ⊥, r4: ¬-c, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,c,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {-c c r2} <a: ⊥, r1: ⊥, b: r2 ∨ ⊥, r2: ⊥, r3: c, c: ⊥, r4: ¬-c, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,cmp(c) }
#                    model: False
#           grounded model: False
#                   reduct: {a -c cmp(c)} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,b,cmp(c) }
#                    model: False
#           grounded model: False
#                   reduct: {-c b cmp(c)} <a: ⊥, r1: b, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,cmp(c),r2 }
#                    model: False
#           grounded model: False
#                   reduct: {-c r2 cmp(c)} <a: ⊥, r1: ⊥, b: r2 ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,a,b }
#                    model: False
#           grounded model: False
#                   reduct: {a -c b} <a: ⊥, r1: b, b: ⊥ ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,a,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {a -c r2} <a: ⊥, r1: ⊥, b: r2 ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,b,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {-c b r2} <a: ⊥, r1: b, b: r2 ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { r1,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r5 r4} <a: r1, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: r4, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 r5 r4} <a: ⊥, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: r4, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { c,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {c r5 r4} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: c, c: r4, r4: ⊤, -c: r5, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { cmp(c),r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 cmp(c)} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: r4, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { a,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {a r5 r4} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: a, r3: ⊥, c: r4, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { b,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 b r4} <a: ⊥, r1: b, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: r4, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { r2,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r2} <a: ⊥, r1: ⊥, b: r2 ∨ ⊥, r2: ⊥, r3: ⊥, c: r4, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { r1,r3,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r3 r5} <a: r1, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { c,r1,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r5 c} <a: r1, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: c, c: ⊥, r4: ⊤, -c: r5, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { cmp(c),r1,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r5 cmp(c)} <a: r1, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { a,r1,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 a r5} <a: r1, r1: ⊥, b: ⊥ ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { b,r1,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r5 b} <a: r1, r1: b, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { r1,r2,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r5 r2} <a: r1, r1: ⊥, b: r2 ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { c,r3,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 r5 c} <a: ⊥, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: c, c: ⊥, r4: ⊤, -c: r5, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { cmp(c),r3,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 r5 cmp(c)} <a: ⊥, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { a,r3,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 a r5} <a: ⊥, r1: ⊥, b: ⊥ ∨ r3, r2: a, r3: ⊥, c: ⊥, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { b,r3,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 r5 b} <a: ⊥, r1: b, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { r2,r3,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 r5 r2} <a: ⊥, r1: ⊥, b: r2 ∨ r3, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { c,cmp(c),r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 c cmp(c)} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: c, c: ⊥, r4: ⊤, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ ⊥>
# grounded model of reduct: False
# { a,c,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {a r5 c} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: a, r3: c, c: ⊥, r4: ⊤, -c: r5, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { b,c,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 b c} <a: ⊥, r1: b, b: ⊥ ∨ ⊥, r2: ⊥, r3: c, c: ⊥, r4: ⊤, -c: r5, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { c,r2,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 c r2} <a: ⊥, r1: ⊥, b: r2 ∨ ⊥, r2: ⊥, r3: c, c: ⊥, r4: ⊤, -c: r5, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { a,cmp(c),r5 }
#                    model: False
#           grounded model: False
#                   reduct: {a r5 cmp(c)} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { b,cmp(c),r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 b cmp(c)} <a: ⊥, r1: b, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { cmp(c),r2,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r2 cmp(c)} <a: ⊥, r1: ⊥, b: r2 ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { a,b,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {a r5 b} <a: ⊥, r1: b, b: ⊥ ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { a,r2,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {a r5 r2} <a: ⊥, r1: ⊥, b: r2 ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { b,r2,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 b r2} <a: ⊥, r1: b, b: r2 ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { r1,r3,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r3 r4} <a: r1, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: r4, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { c,r1,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r4 c} <a: r1, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: c, c: r4, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { cmp(c),r1,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r4 cmp(c)} <a: r1, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: r4, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { a,r1,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 a r4} <a: r1, r1: ⊥, b: ⊥ ∨ ⊥, r2: a, r3: ⊥, c: r4, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { b,r1,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r4 b} <a: r1, r1: b, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: r4, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { r1,r2,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r4 r2} <a: r1, r1: ⊥, b: r2 ∨ ⊥, r2: ⊥, r3: ⊥, c: r4, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { c,r3,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 r4 c} <a: ⊥, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: c, c: r4, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: True
# { cmp(c),r3,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 r4 cmp(c)} <a: ⊥, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: r4, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { a,r3,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 a r4} <a: ⊥, r1: ⊥, b: ⊥ ∨ r3, r2: a, r3: ⊥, c: r4, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { b,r3,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 r4 b} <a: ⊥, r1: b, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: r4, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { r2,r3,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 r4 r2} <a: ⊥, r1: ⊥, b: r2 ∨ r3, r2: ⊥, r3: ⊥, c: r4, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { c,cmp(c),r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r4 c cmp(c)} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: c, c: r4, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ ⊥>
# grounded model of reduct: False
# { a,c,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {a r4 c} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: a, r3: c, c: r4, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { b,c,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r4 b c} <a: ⊥, r1: b, b: ⊥ ∨ ⊥, r2: ⊥, r3: c, c: r4, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { c,r2,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r4 c r2} <a: ⊥, r1: ⊥, b: r2 ∨ ⊥, r2: ⊥, r3: c, c: r4, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { a,cmp(c),r4 }
#                    model: False
#           grounded model: False
#                   reduct: {a r4 cmp(c)} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: a, r3: ⊥, c: r4, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { b,cmp(c),r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r4 b cmp(c)} <a: ⊥, r1: b, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: r4, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { cmp(c),r2,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r4 r2 cmp(c)} <a: ⊥, r1: ⊥, b: r2 ∨ ⊥, r2: ⊥, r3: ⊥, c: r4, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { a,b,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {a r4 b} <a: ⊥, r1: b, b: ⊥ ∨ ⊥, r2: a, r3: ⊥, c: r4, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { a,r2,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {a r4 r2} <a: ⊥, r1: ⊥, b: r2 ∨ ⊥, r2: a, r3: ⊥, c: r4, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { b,r2,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r4 b r2} <a: ⊥, r1: b, b: r2 ∨ ⊥, r2: ⊥, r3: ⊥, c: r4, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { c,r1,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r3 c} <a: r1, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: c, c: ⊥, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { cmp(c),r1,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r3 cmp(c)} <a: r1, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { a,r1,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 a r3} <a: r1, r1: ⊥, b: ⊥ ∨ r3, r2: a, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { b,r1,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r3 b} <a: r1, r1: b, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { r1,r2,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r3 r2} <a: r1, r1: ⊥, b: r2 ∨ r3, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { c,cmp(c),r1 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 c cmp(c)} <a: r1, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: c, c: ⊥, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ ⊥>
# grounded model of reduct: False
# { a,c,r1 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 a c} <a: r1, r1: ⊥, b: ⊥ ∨ ⊥, r2: a, r3: c, c: ⊥, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { b,c,r1 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 b c} <a: r1, r1: b, b: ⊥ ∨ ⊥, r2: ⊥, r3: c, c: ⊥, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { c,r1,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 c r2} <a: r1, r1: ⊥, b: r2 ∨ ⊥, r2: ⊥, r3: c, c: ⊥, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { a,cmp(c),r1 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 a cmp(c)} <a: r1, r1: ⊥, b: ⊥ ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { b,cmp(c),r1 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 b cmp(c)} <a: r1, r1: b, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { cmp(c),r1,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r2 cmp(c)} <a: r1, r1: ⊥, b: r2 ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { a,b,r1 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 a b} <a: r1, r1: b, b: ⊥ ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { a,r1,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 a r2} <a: r1, r1: ⊥, b: r2 ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { b,r1,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 b r2} <a: r1, r1: b, b: r2 ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { c,cmp(c),r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 c cmp(c)} <a: ⊥, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: c, c: ⊥, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ ⊥>
# grounded model of reduct: False
# { a,c,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 a c} <a: ⊥, r1: ⊥, b: ⊥ ∨ r3, r2: a, r3: c, c: ⊥, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { b,c,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 b c} <a: ⊥, r1: b, b: ⊥ ∨ r3, r2: ⊥, r3: c, c: ⊥, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { c,r2,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 c r2} <a: ⊥, r1: ⊥, b: r2 ∨ r3, r2: ⊥, r3: c, c: ⊥, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { a,cmp(c),r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 a cmp(c)} <a: ⊥, r1: ⊥, b: ⊥ ∨ r3, r2: a, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { b,cmp(c),r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 b cmp(c)} <a: ⊥, r1: b, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { cmp(c),r2,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 r2 cmp(c)} <a: ⊥, r1: ⊥, b: r2 ∨ r3, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { a,b,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 a b} <a: ⊥, r1: b, b: ⊥ ∨ r3, r2: a, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { a,r2,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 a r2} <a: ⊥, r1: ⊥, b: r2 ∨ r3, r2: a, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { b,r2,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 b r2} <a: ⊥, r1: b, b: r2 ∨ r3, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { a,c,cmp(c) }
#                    model: False
#           grounded model: False
#                   reduct: {a c cmp(c)} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: a, r3: c, c: ⊥, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ ⊥>
# grounded model of reduct: False
# { b,c,cmp(c) }
#                    model: False
#           grounded model: False
#                   reduct: {b c cmp(c)} <a: ⊥, r1: b, b: ⊥ ∨ ⊥, r2: ⊥, r3: c, c: ⊥, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ ⊥>
# grounded model of reduct: False
# { c,cmp(c),r2 }
#                    model: False
#           grounded model: False
#                   reduct: {r2 c cmp(c)} <a: ⊥, r1: ⊥, b: r2 ∨ ⊥, r2: ⊥, r3: c, c: ⊥, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ ⊥>
# grounded model of reduct: False
# { a,b,c }
#                    model: False
#           grounded model: False
#                   reduct: {a b c} <a: ⊥, r1: b, b: ⊥ ∨ ⊥, r2: a, r3: c, c: ⊥, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { a,c,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {a c r2} <a: ⊥, r1: ⊥, b: r2 ∨ ⊥, r2: a, r3: c, c: ⊥, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { b,c,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {b c r2} <a: ⊥, r1: b, b: r2 ∨ ⊥, r2: ⊥, r3: c, c: ⊥, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { a,b,cmp(c) }
#                    model: False
#           grounded model: False
#                   reduct: {a b cmp(c)} <a: ⊥, r1: b, b: ⊥ ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { a,cmp(c),r2 }
#                    model: False
#           grounded model: False
#                   reduct: {a r2 cmp(c)} <a: ⊥, r1: ⊥, b: r2 ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { b,cmp(c),r2 }
#                    model: False
#           grounded model: False
#                   reduct: {b r2 cmp(c)} <a: ⊥, r1: b, b: r2 ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { a,b,r2 }
#                    model: False
#           grounded model: False
#                   reduct: {a b r2} <a: ⊥, r1: b, b: r2 ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ⊤, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { -c,r1,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 -c r1 r4} <a: r1, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: r4, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r3 -c r4} <a: ⊥, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: r4, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,c,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 -c r4 c} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: c, c: r4, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ⊤ ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,cmp(c),r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 -c r4 cmp(c)} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: r4, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,a,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 a -c r4} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: a, r3: ⊥, c: r4, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,b,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 -c b r4} <a: ⊥, r1: b, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: r4, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,r2,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 -c r4 r2} <a: ⊥, r1: ⊥, b: r2 ∨ ⊥, r2: ⊥, r3: ⊥, c: r4, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,r1,r3,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r3 -c r1} <a: r1, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,c,r1,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 -c r1 c} <a: r1, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: c, c: ⊥, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ⊤ ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,cmp(c),r1,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 -c r1 cmp(c)} <a: r1, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,a,r1,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 a -c r1} <a: r1, r1: ⊥, b: ⊥ ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,b,r1,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 b -c r1} <a: r1, r1: b, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,r1,r2,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 -c r1 r2} <a: r1, r1: ⊥, b: r2 ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,c,r3,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r3 -c c} <a: ⊥, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: c, c: ⊥, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ⊤ ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,cmp(c),r3,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r3 -c cmp(c)} <a: ⊥, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,a,r3,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r3 a -c} <a: ⊥, r1: ⊥, b: ⊥ ∨ r3, r2: a, r3: ⊥, c: ⊥, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,b,r3,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r3 -c b} <a: ⊥, r1: b, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,r2,r3,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r3 -c r2} <a: ⊥, r1: ⊥, b: r2 ∨ r3, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,c,cmp(c),r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 -c c cmp(c)} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: ⊥, r3: c, c: ⊥, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,c,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 a -c c} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: a, r3: c, c: ⊥, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ⊤ ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,b,c,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 -c b c} <a: ⊥, r1: b, b: ⊥ ∨ ⊥, r2: ⊥, r3: c, c: ⊥, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ⊤ ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,c,r2,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 -c c r2} <a: ⊥, r1: ⊥, b: r2 ∨ ⊥, r2: ⊥, r3: c, c: ⊥, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ⊤ ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,cmp(c),r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 a -c cmp(c)} <a: ⊥, r1: ⊥, b: ⊥ ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,b,cmp(c),r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 -c b cmp(c)} <a: ⊥, r1: b, b: ⊥ ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,cmp(c),r2,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 -c r2 cmp(c)} <a: ⊥, r1: ⊥, b: r2 ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,a,b,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 a -c b} <a: ⊥, r1: b, b: ⊥ ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,a,r2,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 a -c r2} <a: ⊥, r1: ⊥, b: r2 ∨ ⊥, r2: a, r3: ⊥, c: ⊥, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,b,r2,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 -c b r2} <a: ⊥, r1: b, b: r2 ∨ ⊥, r2: ⊥, r3: ⊥, c: ⊥, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,r1,r3,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r3 -c r4} <a: r1, r1: ⊥, b: ⊥ ∨ r3, r2: ⊥, r3: ⊥, c: r4, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,c,r1,r4 }
#                    model: False
#           grounded model: False
# ...
# grounded model of reduct: False
# { a,b,c,cmp(c),r2,r3,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r3 b c cmp(c) a r4 r2} <a: ⊥, r1: b, b: r2 ∨ r3, r2: a, r3: c, c: r4, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ ⊥>
# grounded model of reduct: False
# { a,b,c,cmp(c),r1,r2,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r3 c cmp(c) a b r2} <a: r1, r1: b, b: r2 ∨ r3, r2: a, r3: c, c: ⊥, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ ⊥>
# grounded model of reduct: False
# { -c,a,c,cmp(c),r1,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r3 r1 c cmp(c) a -c} <a: r1, r1: ⊥, b: ⊥ ∨ r3, r2: a, r3: c, c: r4, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,b,c,cmp(c),r1,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r3 r1 b c cmp(c) -c} <a: r1, r1: b, b: ⊥ ∨ r3, r2: ⊥, r3: c, c: r4, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,c,cmp(c),r1,r2,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r3 r1 c cmp(c) -c r2} <a: r1, r1: ⊥, b: r2 ∨ r3, r2: ⊥, r3: c, c: r4, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,b,c,r1,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r3 r1 b c a -c} <a: r1, r1: b, b: ⊥ ∨ r3, r2: a, r3: c, c: r4, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ⊤ ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,c,r1,r2,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r3 r1 c a -c r2} <a: r1, r1: ⊥, b: r2 ∨ r3, r2: a, r3: c, c: r4, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ⊤ ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,b,c,r1,r2,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r3 r1 b c -c r2} <a: r1, r1: b, b: r2 ∨ r3, r2: ⊥, r3: c, c: r4, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ⊤ ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,b,cmp(c),r1,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r3 r1 b cmp(c) a -c} <a: r1, r1: b, b: ⊥ ∨ r3, r2: a, r3: ⊥, c: r4, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,a,cmp(c),r1,r2,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r3 r1 cmp(c) a -c r2} <a: r1, r1: ⊥, b: r2 ∨ r3, r2: a, r3: ⊥, c: r4, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,b,cmp(c),r1,r2,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r3 r1 b cmp(c) -c r2} <a: r1, r1: b, b: r2 ∨ r3, r2: ⊥, r3: ⊥, c: r4, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,a,b,r1,r2,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r3 r1 b a -c r2} <a: r1, r1: b, b: r2 ∨ r3, r2: a, r3: ⊥, c: r4, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ⊤ ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,a,b,c,cmp(c),r1,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r1 b c cmp(c) a -c} <a: r1, r1: b, b: ⊥ ∨ ⊥, r2: a, r3: c, c: r4, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,c,cmp(c),r1,r2,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r1 c cmp(c) a -c r2} <a: r1, r1: ⊥, b: r2 ∨ ⊥, r2: a, r3: c, c: r4, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,b,c,cmp(c),r1,r2,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r1 b c cmp(c) -c r2} <a: r1, r1: b, b: r2 ∨ ⊥, r2: ⊥, r3: c, c: r4, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,b,c,r1,r2,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r1 b c a -c r2} <a: r1, r1: b, b: r2 ∨ ⊥, r2: a, r3: c, c: r4, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ⊤ ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,b,cmp(c),r1,r2,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r1 b cmp(c) a -c r2} <a: r1, r1: b, b: r2 ∨ ⊥, r2: a, r3: ⊥, c: r4, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,a,b,c,cmp(c),r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r3 b c cmp(c) a -c} <a: ⊥, r1: b, b: ⊥ ∨ r3, r2: a, r3: c, c: r4, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,c,cmp(c),r2,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r3 c cmp(c) a -c r2} <a: ⊥, r1: ⊥, b: r2 ∨ r3, r2: a, r3: c, c: r4, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,b,c,cmp(c),r2,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r3 b c cmp(c) -c r2} <a: ⊥, r1: b, b: r2 ∨ r3, r2: ⊥, r3: c, c: r4, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,b,c,r2,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r3 b c a -c r2} <a: ⊥, r1: b, b: r2 ∨ r3, r2: a, r3: c, c: r4, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ⊤ ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,b,cmp(c),r2,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r3 b cmp(c) a -c r2} <a: ⊥, r1: b, b: r2 ∨ r3, r2: a, r3: ⊥, c: r4, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,a,b,c,cmp(c),r2,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 b c cmp(c) a -c r2} <a: ⊥, r1: b, b: r2 ∨ ⊥, r2: a, r3: c, c: r4, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,b,c,cmp(c),r1,r3,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r3 r1 b c cmp(c) a -c} <a: r1, r1: b, b: ⊥ ∨ r3, r2: a, r3: c, c: ⊥, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,c,cmp(c),r1,r2,r3,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r3 r1 c cmp(c) a -c r2} <a: r1, r1: ⊥, b: r2 ∨ r3, r2: a, r3: c, c: ⊥, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,b,c,cmp(c),r1,r2,r3,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r3 r1 b c cmp(c) -c r2} <a: r1, r1: b, b: r2 ∨ r3, r2: ⊥, r3: c, c: ⊥, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,b,c,r1,r2,r3,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r3 r1 b c a -c r2} <a: r1, r1: b, b: r2 ∨ r3, r2: a, r3: c, c: ⊥, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ⊤ ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,b,cmp(c),r1,r2,r3,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r3 r1 b cmp(c) a -c r2} <a: r1, r1: b, b: r2 ∨ r3, r2: a, r3: ⊥, c: ⊥, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,a,b,c,cmp(c),r1,r2,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r1 b c cmp(c) a -c r2} <a: r1, r1: b, b: r2 ∨ ⊥, r2: a, r3: c, c: ⊥, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,b,c,cmp(c),r2,r3,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r3 b c cmp(c) a -c r2} <a: ⊥, r1: b, b: r2 ∨ r3, r2: a, r3: c, c: ⊥, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,b,c,cmp(c),r1,r3,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r4 r1 r3 b c cmp(c) a -c} <a: r1, r1: b, b: ⊥ ∨ r3, r2: a, r3: c, c: r4, r4: ¬-c, -c: ⊥, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,c,cmp(c),r1,r2,r3,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r4 r1 r3 c cmp(c) a -c r2} <a: r1, r1: ⊥, b: r2 ∨ r3, r2: a, r3: c, c: r4, r4: ¬-c, -c: ⊥, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,b,c,cmp(c),r1,r2,r3,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r4 r1 r3 b c cmp(c) -c r2} <a: r1, r1: b, b: r2 ∨ r3, r2: ⊥, r3: c, c: r4, r4: ¬-c, -c: ⊥, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,b,c,r1,r2,r3,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r4 r1 r3 b c a -c r2} <a: r1, r1: b, b: r2 ∨ r3, r2: a, r3: c, c: r4, r4: ¬-c, -c: ⊥, r5: ¬c, cmp(c): ⊤ ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,b,cmp(c),r1,r2,r3,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r4 r1 r3 b cmp(c) a -c r2} <a: r1, r1: b, b: r2 ∨ r3, r2: a, r3: ⊥, c: r4, r4: ¬-c, -c: ⊥, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,a,b,c,cmp(c),r1,r2,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r4 r1 b c cmp(c) a -c r2} <a: r1, r1: b, b: r2 ∨ ⊥, r2: a, r3: c, c: r4, r4: ¬-c, -c: ⊥, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,b,c,cmp(c),r2,r3,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r4 r3 b c cmp(c) a -c r2} <a: ⊥, r1: b, b: r2 ∨ r3, r2: a, r3: c, c: r4, r4: ¬-c, -c: ⊥, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,b,c,cmp(c),r1,r2,r3 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r3 b c cmp(c) a -c r2} <a: r1, r1: b, b: r2 ∨ r3, r2: a, r3: c, c: ⊥, r4: ¬-c, -c: ⊥, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { a,b,c,cmp(c),r1,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r1 r3 b c cmp(c) a r4} <a: r1, r1: b, b: ⊥ ∨ r3, r2: a, r3: c, c: r4, r4: ⊤, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ ⊥>
# grounded model of reduct: False
# { a,c,cmp(c),r1,r2,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r1 r3 c cmp(c) a r4 r2} <a: r1, r1: ⊥, b: r2 ∨ r3, r2: a, r3: c, c: r4, r4: ⊤, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ ⊥>
# grounded model of reduct: False
# { b,c,cmp(c),r1,r2,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r1 r3 b c cmp(c) r4 r2} <a: r1, r1: b, b: r2 ∨ r3, r2: ⊥, r3: c, c: r4, r4: ⊤, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ ⊥>
# grounded model of reduct: False
# { a,b,c,r1,r2,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r1 r3 b c a r4 r2} <a: r1, r1: b, b: r2 ∨ r3, r2: a, r3: c, c: r4, r4: ⊤, -c: r5, r5: ¬c, cmp(c): ⊤ ∧ c ∧ ⊥>
# grounded model of reduct: False
# { a,b,cmp(c),r1,r2,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r1 r3 b cmp(c) a r4 r2} <a: r1, r1: b, b: r2 ∨ r3, r2: a, r3: ⊥, c: r4, r4: ⊤, -c: r5, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ ⊥>
# grounded model of reduct: False
# { a,b,c,cmp(c),r1,r2,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r1 b c cmp(c) a r4 r2} <a: r1, r1: b, b: r2 ∨ ⊥, r2: a, r3: c, c: r4, r4: ⊤, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ ⊥>
# grounded model of reduct: False
# { a,b,c,cmp(c),r2,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r3 b c cmp(c) a r4 r2} <a: ⊥, r1: b, b: r2 ∨ r3, r2: a, r3: c, c: r4, r4: ⊤, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ ⊥>
# grounded model of reduct: False
# { a,b,c,cmp(c),r1,r2,r3,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r1 r3 c cmp(c) a b r2} <a: r1, r1: b, b: r2 ∨ r3, r2: a, r3: c, c: ⊥, r4: ⊤, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ ⊥>
# grounded model of reduct: False
# { a,b,c,cmp(c),r1,r2,r3,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r1 r3 b c cmp(c) a r4 r2} <a: r1, r1: b, b: r2 ∨ r3, r2: a, r3: c, c: r4, r4: ⊤, -c: ⊥, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ ⊥>
# grounded model of reduct: False
# { -c,a,b,c,cmp(c),r1,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r3 r1 b c cmp(c) a -c} <a: r1, r1: b, b: ⊥ ∨ r3, r2: a, r3: c, c: r4, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,c,cmp(c),r1,r2,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r3 r1 c cmp(c) a -c r2} <a: r1, r1: ⊥, b: r2 ∨ r3, r2: a, r3: c, c: r4, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,b,c,cmp(c),r1,r2,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r3 r1 b c cmp(c) -c r2} <a: r1, r1: b, b: r2 ∨ r3, r2: ⊥, r3: c, c: r4, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,b,c,r1,r2,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r3 r1 b c a -c r2} <a: r1, r1: b, b: r2 ∨ r3, r2: a, r3: c, c: r4, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ⊤ ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,b,cmp(c),r1,r2,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r3 r1 b cmp(c) a -c r2} <a: r1, r1: b, b: r2 ∨ r3, r2: a, r3: ⊥, c: r4, r4: ¬-c, -c: r5, r5: ⊤, cmp(c): ¬cmp(c) ∧ ⊥ ∧ -c>
# grounded model of reduct: False
# { -c,a,b,c,cmp(c),r1,r2,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r1 b c cmp(c) a -c r2} <a: r1, r1: b, b: r2 ∨ ⊥, r2: a, r3: c, c: r4, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,b,c,cmp(c),r2,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r3 b c cmp(c) a -c r2} <a: ⊥, r1: b, b: r2 ∨ r3, r2: a, r3: c, c: r4, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,b,c,cmp(c),r1,r2,r3,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r3 r1 b c cmp(c) a -c r2} <a: r1, r1: b, b: r2 ∨ r3, r2: a, r3: c, c: ⊥, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { -c,a,b,c,cmp(c),r1,r2,r3,r4 }
#                    model: False
#           grounded model: False
#                   reduct: {r4 r1 r3 b c cmp(c) a -c r2} <a: r1, r1: b, b: r2 ∨ r3, r2: a, r3: c, c: r4, r4: ¬-c, -c: ⊥, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False
# { a,b,c,cmp(c),r1,r2,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r1 r3 b c cmp(c) a r4 r2} <a: r1, r1: b, b: r2 ∨ r3, r2: a, r3: c, c: r4, r4: ⊤, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ ⊥>
# grounded model of reduct: False
# { -c,a,b,c,cmp(c),r1,r2,r3,r4,r5 }
#                    model: False
#           grounded model: False
#                   reduct: {r5 r4 r3 r1 b c cmp(c) a -c r2} <a: r1, r1: b, b: r2 ∨ r3, r2: a, r3: c, c: r4, r4: ¬-c, -c: r5, r5: ¬c, cmp(c): ¬cmp(c) ∧ c ∧ -c>
# grounded model of reduct: False

# %%
s = ASPBasicLiteral.make_literal('s')
t = ASPBasicLiteral.make_literal('t')
nt = ASPBasicLiteral.make_literal('-t')
u = ASPBasicLiteral.make_literal('u')
c = ASPBasicLiteral.make_literal('c')
i = ASPBasicLiteral.make_literal('i')
a = ASPBasicLiteral.make_literal('a')
b = ASPBasicLiteral.make_literal('b')

r1 = ASPNormalRule(s, (c, -t))
r2 = ASPNormalRule(s, (nt,))
r3 = ASPNormalRule(u, (-s,))
r4 = ASPNormalRule(c, (a, -i,))
r5 = ASPNormalRule(i, (b, -c,))
r6 = ASPNormalRule(nt, (-a,))
r7 = ASPNormalRule(a, (-nt,))
r8 = ASPNormalRule(t, (-b,))
r9 = ASPNormalRule(b, (-t,))

rs = (r1, r2, r3, r4, r5, r6, r7, r8, r9)

prg = make_program(*rs)
print(prg)
# Out:
# s :- c, not t.
# s :- -t.
# u :- not s.
# c :- a, not i.
# i :- b, not c.
# -t :- not a.
# a :- not -t.
# t :- not b.
# b :- not t.

# %%
answer_sets = tuple(asp_evaluate(prg, report=True))
# Out:
# Answer 1: { a b c s }
# Answer 2: { a c t u }
# Answer 3: { a b i u }
# Answer 4: { b i s -t }
# SAT 4

# %%
adf = asp_to_adf(*rs)
print(adf)
# Out:
# {r6 r5 r8 t r1 s r3 r7 cmp(t) b c u r9 a r4 i r2 -t} <s: r1 ∨ r2, r1: c ∧ ¬t, r2: -t, u: r3, r3: ¬s, c: r4, r4: a ∧ ¬i, i: r5, r5: ¬c ∧ b, -t: r6, r6: ¬a, a: r7, r7: ¬-t, t: r8, r8: ¬b, b: r9, r9: ¬t, cmp(t): ¬cmp(t) ∧ t ∧ -t>

# %%
for model in adf_models(adf):
    print('{', ','.join(map(str, sorted(model))), '}')
    print('is grounded model:', maybe_grounded_model(adf, model, adf.statements-model))
    red = reduct(adf, model)
    print('reduct:', red)
    print('is grounded model of reduct:', maybe_grounded_model(red, model, set()))
# Out:
# { -t,b,i,r2,r5,r6,r9,s }
# is grounded model: True
# reduct: {r6 r5 s r9 b i r2 -t} <s: ⊥ ∨ r2, r1: ⊥ ∧ ⊤, r2: -t, u: ⊥, r3: ¬s, c: ⊥, r4: ⊥ ∧ ¬i, i: r5, r5: ⊤ ∧ b, -t: r6, r6: ⊤, a: ⊥, r7: ¬-t, t: ⊥, r8: ¬b, b: r9, r9: ⊤, cmp(t): ⊤ ∧ ⊥ ∧ -t>
# is grounded model of reduct: True
# { a,b,i,r3,r5,r7,r9,u }
# is grounded model: True
# reduct: {r5 r3 r7 u r9 a b i} <s: ⊥ ∨ ⊥, r1: ⊥ ∧ ⊤, r2: ⊥, u: r3, r3: ⊤, c: ⊥, r4: a ∧ ¬i, i: r5, r5: ⊤ ∧ b, -t: ⊥, r6: ¬a, a: r7, r7: ⊤, t: ⊥, r8: ¬b, b: r9, r9: ⊤, cmp(t): ⊤ ∧ ⊥ ∧ ⊥>
# is grounded model of reduct: True
# { a,c,r3,r4,r7,r8,t,u }
# is grounded model: True
# reduct: {r8 t r3 r7 c u a r4} <s: ⊥ ∨ ⊥, r1: c ∧ ¬t, r2: ⊥, u: r3, r3: ⊤, c: r4, r4: a ∧ ⊤, i: ⊥, r5: ¬c ∧ ⊥, -t: ⊥, r6: ¬a, a: r7, r7: ⊤, t: r8, r8: ⊤, b: ⊥, r9: ¬t, cmp(t): ⊤ ∧ t ∧ ⊥>
# is grounded model of reduct: True
# { a,b,c,r1,r4,r7,r9,s }
# is grounded model: True
# reduct: {r4 r1 s r7 c r9 a b} <s: r1 ∨ ⊥, r1: c ∧ ⊤, r2: ⊥, u: ⊥, r3: ¬s, c: r4, r4: a ∧ ⊤, i: ⊥, r5: ¬c ∧ b, -t: ⊥, r6: ¬a, a: r7, r7: ⊤, t: ⊥, r8: ¬b, b: r9, r9: ⊤, cmp(t): ⊤ ∧ ⊥ ∧ ⊥>
# is grounded model of reduct: True

# %%
#for assignment_ in powerset(adf.statements):
#    print('{', ','.join(map(str, sorted(assignment_))), '}')
#    extension = set(assignment_)
#    print('         Model:', is_model(adf, extension))
#    print('Grounded Model:', maybe_grounded_model(adf, extension, adf.statements - extension))
#    print('        Reduct:', reduct(adf, extension))
